# %% [markdown]
# ls -la
# pwd

# %% [markdown]
# 4 - read
# 2 - write
# 1 - execute
#
# sudo chmod {user,group,other} "file_name"
#
# sudo chmod 744

# %% [markdown]
# touch learn_bash.sh

# %% [markdown]
# #!/bin/bash
# #!/usr/bin/env bash
#
# shebang

# %% [markdown]
# #!/usr/bin/env bash

# %% [markdown]
# #!/bin/bash
#
# echo "Hello World!"

# %% [markdown]
# sudo chmod +x learn_bash.sh

# %% [markdown]
# ./learn_bash.sh

# %% [markdown]
# bash learn_bash.sh

# %% [markdown]
# # variable declaring
#
# name="debian"
#
# # printing the variable
#
# echo "$name"

# %% [markdown]
# ```sh
# #!/bin/bash
#
# filename="my file.txt"
#
# #touch $filename
#
# touch "$filename"
# ```

# %% [markdown]
# greeting="Hello"
#
# #echo "$greetings world"
#
# echo "${greeting}s world"

# %% [markdown]
# #!/bin/bash
#
# name="debian"
#
# echo "Hi there ${name}"

# %% [markdown]
# #!/bin/bash
#
# framework="fastapi"
# language="python"
# database="postgresql"
#
# echo "${framework} ${language} ${database}"
# L

# %% [markdown]
# #!/bin/bash
#
# echo "Hello there $1"

# %% [markdown]
# #!/bin/bash
#
# echo "Hello there $1"
#
# echo "Hello there $2"
#
# echo "Hello there $@"

# %% [markdown]
# #!/bin/bash
# echo "what is your name?"
# read name
#
# echo "Hi there $name"
# echo "Welcome to Linux!"

# %% [markdown]
# #!/bin/bash
#
# read -p "what is your name?" name
#
# echo "Hi there $name"
#
# echo "Welcome to Linux!"

# %% [markdown]
# #!/bin/bash
#
# # Ask the user for their name
#
# read -p "what is your name?" name
#
# # Greet the user
#
# echo "Hi there $name"
# echo "Welcome to Linux!"

# %% [markdown]
# #!/bin/bash
#
# echo "The name of the file is: ${0} and it is going to be self deleted."
#
# rm -f "${0}"

# %% [markdown]
# my_array=("value 1" 12 "value 2" "value 3" "value 4")
#
#  <!-- use curly braces and double quotes around array  -->

# %% [markdown]
# Slicing syntax
#
# ${string:start_index:lenght}
# ${string:start_index:lenght}

# %% [markdown]
# echo "${my_array[1]}"
# echo "${my_array[0]}"

# %% [markdown]
# echo "${my_array[-1]}"
# echo "${my_array[@]}"

# %% [markdown]
# echo "${#my_array[@]}"

# %% [markdown]
# #!/bin/bash
#
# array=("A" "B" "C" "D" "E")
#
# # Print entire array
#
# echo "${array[@]}"
#
# # Access a single element
#
# echo "${array[1]}"
#
# # Print a range of elements
#
# echo "${array[@]:1:3}"
#
# # Print from an index to the end
#
# echo "${array[@]:3}"

# %% [markdown]
# ${string:start:length}

# %% [markdown]
# #!/bin/bash
#
# text="ABCDE"
#
# # Extract from index 0, maximum 2 characters
#
# echo "${}"
#
# # Extract from index 3 to the end
#
# echo "${}"
#
# # Extract 3 characters starting from index 1
#
# echo "${}"
#
# echo "${text:3:3}"

# %% [markdown]
# text="Hello, World!"
#
# echo "${text:7:5}"
#
# echo "${text:7:10}"

# %% [markdown]
# true if a file exists

# %% [markdown]
# # File expressions
#
# ```sh
# [[ -e devops.sh ]]
# ```

# %% [markdown]
# true if a dir exists

# %% [markdown]
# ```sh
# [[ -d folder ]]
# ```

# %% [markdown]
# true if a file is readable

# %% [markdown]
# ```sh
# [[ -r {file} ]]
# ```

# %% [markdown]
# true if size greater than zero

# %% [markdown]
# ```sh
# [[ -s {file} ]]
# ```

# %% [markdown]
# true if a file is writable

# %% [markdown]
# ```sh
# [[ -w {file} ]]
# ```

# %% [markdown]
# true if a file is executable

# %% [markdown]
# ```sh
# [[ -x {file} ]]
# ```

# %% [markdown]
# string length equals zero

# %% [markdown]
# #!/bin/bash
#
# data=""
#
# if [[-z "${data}"]]
# then
# echo "True"
# fi

# %% [markdown]
# string length not zero

# %% [markdown]
# if [[-n "${data}"]]

# %% [markdown]
# #!/bin/bash
#
# data1="asdf"
# data2="asdfa"
#
# if [["${data1}" != "${data2}"]]
# then
# echo "True"
# fi

# %% [markdown]
# #!/bin/bash
#
# data1=88
# data2=77
#
# if [["${data1}" < "${data2}"]]
# then
# echo "True"
# else
# echo "False"
# fi

# %% [markdown]
# #!/bin/bash
#
# admin="debian"
#
# read -p "Enter your username?" username
#
# if [["${admin}" == "${username}"]] ;
# then echo "Your are the admin user"
# else echo "Your are NOT the admin user"
# fi

# %% [markdown]
# #!/bin/bash
#
# if (( $EUID == 0 )) ; then
# echo "Please do not run as root"
# exit
# fi

# %% [markdown]
# #!/bin/bash
#
# for num in {1..10} ;
# do
# echo "$num"
# done

# %% [markdown]
# #!/bin/bash
#
# distros=("debain" "BlackArch" "fedora")
#
# for distro in "${distros[@]}"
# do
#     echo "$distro"
# done

# %% [markdown]
# #!/bin/bash
#
# counter=10
#
# while [[$counter -le 20]]
# do
# echo "$counter"
# ((counter++))
# done

# %% [markdown]
# mkdir -p ~/devops/2026_05_20/new_script
#
# echo "###############################"
# echo "new_script folder is created"
# echo "###############################"
#
# cd ~/devops/2026_05_20/new_script
#
# echo "###############################"
# echo "we moved to new_script folder"
# echo "###############################"
#
# touch main.py
#
# echo "###############################"
# echo "main.py python file is created"
# echo "###############################"
#
# echo "print('python3 was used')" > main.py
#
# echo "###############################"
# echo "main.py python file data added"
# echo "###############################"
#
# python3 main.py

# %% [markdown]
# #!/bin/bash
#
# if [[-e "7.txt"]] # false
# then
# echo "True"
# sudo apt update
# echo "apt update completed successfully!!!"
# elif [[-d "py16"]] # false
# then
# echo "directory founded";
# elif [[-d "devops"]] # true
# then
# echo "devops directory founded";
# else
# echo "False"
# echo "apt not installed "
# fi

# %% [markdown]
# sudo apt install openssh-server
#
# eval "$(ssh-agent -s)"
